# %%
from google.generativeai import GenerativeModel,configure
configure(api_key="AIzaSyD3erP9ziHIfB_1zZXe3LFbdzVVDgiqHOw")
model=GenerativeModel("gemini-1.5-pro")
r=model.generate_content("who are you?")
print(r.text)
r=model.generate_content("India's top most 5 games")
print(r.text)
# Out:
# I am a large language model, trained by Google.
# Defining "top" can be tricky and depends on what criteria you're using.  Here are India's top 5 games based on different interpretations of "top":
#
# **1. By Popularity/Most Played:**
#
# * **Cricket:** Undeniably the most popular sport in India, dominating viewership and participation.
# * **Kabaddi:** A traditional Indian sport that has seen a massive resurgence in popularity thanks to the Pro Kabaddi League.
# * **Badminton:**  India has produced several world-class badminton players, contributing to its growing popularity.
# * **Football (Soccer):**  While cricket reigns supreme, football has a significant and growing following, especially among younger generations.
# * **Mobile Gaming (e.g., PUBG Mobile, Free Fire, etc.):**  The mobile gaming explosion has made this a hugely popular pastime, though it encompasses many individual game titles.
#
# **2. By International Success:**
#
# * **Cricket:**  India is a global powerhouse in cricket, consistently ranking among the top teams.
# * **Badminton:**  India has achieved significant international success in badminton, with Olympic medals and world championship titles.
# * **Hockey:** Historically, India dominated field hockey, winning numerous Olympic gold medals.  While its dominance has waned, it remains an important sport.
# * **Shooting:**  India has won several Olympic medals in shooting.
# * **Wrestling:** India has a strong tradition in wrestling and has produced Olympic medalists.
#
# **3. By Traditional/Cultural Significance:**
#
# * **Kabaddi:**  A deeply rooted traditional sport played across India for centuries.
# * **Kho-Kho:** Another traditional tag-team sport popular in India.
# * **Gilli-Danda:** A traditional street game played with sticks.
# * **Kancha (Marbles):** A popular children's game.
# * **Lattu (Spinning Top):** A traditional toy and game.
#
#
# It's important to remember that this is not an exhaustive list and the order can vary depending on the metrics used and the source consulted.
